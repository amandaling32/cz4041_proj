# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("./csvs/data/train_sber_corrected.csv", encoding= "utf_8")
test = pd.read_csv("./csvs/data/test_sber_corrected.csv", encoding= "utf_8")

# %%
train.loc[train.life_sq > train.full_sq]
# Out:
#           id   timestamp  full_sq  life_sq  floor  max_floor  material  \
# 1084    1085  2012-02-06       44    281.0    6.0        NaN       NaN
# 1188    1189  2012-02-14        9     44.0    3.0        NaN       NaN
# 1822    1825  2012-04-09       18     38.0    NaN        NaN       NaN
# 1863    1866  2012-04-11       30    178.0    4.0        NaN       NaN
# 2009    2012  2012-04-25        5     40.0    5.0        NaN       NaN
# 4385    4388  2012-10-25       73    426.0   17.0        NaN       NaN
# 6336    6339  2013-03-06       37    191.0    5.0        NaN       NaN
# 6531    6534  2013-03-15       80     88.0    9.0        NaN       NaN
# 6993    6996  2013-04-03       73     77.0   10.0        NaN       NaN
# 7208    7211  2013-04-10       31    195.0    5.0        NaN       NaN
# 8101    8104  2013-05-23       37     38.0    8.0        NaN       NaN
# 9237    9240  2013-07-16       47    301.0    4.0       12.0       1.0
# ...

# %%
# bad_index = train[train.life_sq > train.full_sq].index
train.loc[train.life_sq > train.full_sq]["life_sq"] = np.NaN
test.loc[test.life_sq > test.full_sq]["life_sq"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\2595784702.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.life_sq > train.full_sq]["life_sq"] = np.NaN
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\2595784702.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[test.life_sq > test.full_sq]["life_sq"] = np.NaN

# %%
# equal_index = [601,1896,2791]
# test.loc[equal_index, "life_sq"] = test.loc[equal_index, "full_sq"]

# %%
# bad_index = test[test.life_sq > test.full_sq].index
# test.loc[bad_index, "life_sq"] = np.NaN

# %%
# bad_index = train[train.life_sq < 5].index
train.loc[train.life_sq < 5]["life_sq"] = np.NaN
test.loc[test.life_sq < 5]["life_sq"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\4097157686.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.life_sq < 5]["life_sq"] = np.NaN
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\4097157686.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[test.life_sq < 5]["life_sq"] = np.NaN

# %%
# bad_index = test[test.life_sq < 5].index
# test.loc[bad_index, "life_sq"] = np.NaN

# %%
# bad_index = train[train.full_sq < 5].index
train.loc[train.full_sq < 5]["full_sq"] = np.NaN
test.loc[test.full_sq < 5]["full_sq"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\4051366745.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.full_sq < 5]["full_sq"] = np.NaN
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\4051366745.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[test.full_sq < 5]["full_sq"] = np.NaN

# %%
# bad_index = test[test.full_sq < 5].index
# test.loc[bad_index, "full_sq"] = np.NaN

# %%
# kitch_is_build_year = [13117]
# train.loc[kitch_is_build_year, "build_year"] = train.loc[kitch_is_build_year, "kitch_sq"]

# %%
# bad_index = train[train.kitch_sq >= train.life_sq].index
train.loc[train.kitch_sq >= train.life_sq]["kitch_sq"] = np.NaN
test.loc[test.kitch_sq >= test.life_sq]["kitch_sq"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\865366169.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.kitch_sq >= train.life_sq]["kitch_sq"] = np.NaN
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\865366169.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[test.kitch_sq >= test.life_sq]["kitch_sq"] = np.NaN

# %%
# bad_index = test[test.kitch_sq >= test.life_sq].index
# test.loc[bad_index, "kitch_sq"] = np.NaN

# %%
# bad_index = train[(train.kitch_sq == 0).values + (train.kitch_sq == 1).values].index
train.loc[(train.kitch_sq == 0) & (train.kitch_sq == 1)]["kitch_sq"] = np.NaN
test.loc[(test.kitch_sq == 0) & (test.kitch_sq == 1)]["kitch_sq"] = np.NaN

# %%
# bad_index = test[(test.kitch_sq == 0).values + (test.kitch_sq == 1).values].index
# test.loc[bad_index, "kitch_sq"] = np.NaN

# %%
# bad_index = train[(train.full_sq > 210) * (train.life_sq / train.full_sq < 0.3)].index
# train.loc[bad_index, "full_sq"] = np.NaN

# %%
# bad_index = test[(test.full_sq > 150) * (test.life_sq / test.full_sq < 0.3)].index
# test.loc[bad_index, "full_sq"] = np.NaN

# %%
# bad_index = train[train.life_sq > 300].index
train.loc[train.life_sq > 300]["life_sq", "full_sq"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\2541717612.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.life_sq > 300]["life_sq", "full_sq"] = np.NaN

# %%
# bad_index = test[test.life_sq > 200].index
test.loc[test.life_sq > 200]["life_sq", "full_sq"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\676425806.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[test.life_sq > 200]["life_sq", "full_sq"] = np.NaN

# %%
# bad_index = train[train.build_year < 1500].index
train.loc[train.build_year < 1500]["build_year"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\458213884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.build_year < 1500]["build_year"] = np.NaN

# %%
# bad_index = test[test.build_year < 1500].index
test.loc[test.build_year < 1500]["build_year"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\3949217877.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[test.build_year < 1500]["build_year"] = np.NaN

# %%
# bad_index = train[train.num_room == 0].index 
train.loc[train.num_room == 0]["num_room"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\3405883208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.num_room == 0]["num_room"] = np.NaN

# %%
# bad_index = test[test.num_room == 0].index 
test.loc[test.num_room == 0]["num_room"] = np.NaN

# %%
# bad_index = [10076, 11621, 17764, 19390, 24007, 26713, 29172]
# train.loc[bad_index, "num_room"] = np.NaN

# %%
# bad_index = [3174, 7313]
# test.loc[bad_index, "num_room"] = np.NaN

# %%
# bad_index = train[(train.floor == 0).values * (train.max_floor == 0).values].index
# train.loc[bad_index, ["max_floor", "floor"]] = np.NaN

# %%
# bad_index = train[train.floor == 0].index
train.loc[train.floor == 0]["floor"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\3679046723.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.floor == 0]["floor"] = np.NaN

# %%
# bad_index = train[train.max_floor == 0].index
train.loc[train.max_floor == 0]["max_floor"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\4140265236.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.max_floor == 0]["max_floor"] = np.NaN

# %%
# bad_index = test[test.max_floor == 0].index
test.loc[test.max_floor == 0]["max_floor"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\810528316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[test.max_floor == 0]["max_floor"] = np.NaN

# %%
# bad_index = train[train.floor > train.max_floor].index
train.loc[train.floor > train.max_floor]["max_floor"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\129026331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.floor > train.max_floor]["max_floor"] = np.NaN

# %%
# bad_index = test[test.floor > test.max_floor].index
test.loc[test.floor > test.max_floor]["max_floor"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\2341984222.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[test.floor > test.max_floor]["max_floor"] = np.NaN

# %%
# bad_index = [23584]
# train.loc[bad_index, "floor"] = np.NaN

# %%
# bad_index = train[train.state == 33].index
train.loc[train.state == 33]["state"] = np.NaN
# Out:
# C:\Users\wongd\AppData\Local\Temp\ipykernel_44388\3943988562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train.state == 33]["state"] = np.NaN

# %% [markdown]
# ### SAVE TEST & TRAIN AS CLEAN

# %%
test.to_csv("./csvs/data/test_clean.csv", index= False, encoding= "utf_8")
train.to_csv("./csvs/data/train_clean.csv", index = False, encoding= "utf_8")
